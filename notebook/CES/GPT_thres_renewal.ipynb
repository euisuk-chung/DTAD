# %% [markdown]
# ## Module Import & Data Load

# %%
import sys

from pathlib import Path
from datetime import timedelta

import dateutil
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm.notebook import trange
from TaPR_pkg import etapr
from src import dataset
import random
import pickle
from torchinfo import summary
from collections import Counter

# %%
import transformers
from src.models.gpt2 import GPT2Model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.backends.cudnn.benchmark = True

# %%
def set_seed(random_seed):
    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(random_seed)
    random.seed(random_seed)

set_seed(72)

# %%
WINDOW_GIVEN = 254
WINDOW_SIZE = 255


class HaiDataset(Dataset):
    def __init__(self, timestamps, df, stride=1, attacks=None):
        self.ts = np.array(timestamps)
        self.tag_values = np.array(df, dtype=np.float32)
        self.valid_idxs = []
        for L in trange(len(self.ts) - WINDOW_SIZE + 1):
            R = L + WINDOW_SIZE - 1
            if dateutil.parser.parse(self.ts[R]) - dateutil.parser.parse(
                self.ts[L]
            ) == timedelta(seconds=WINDOW_SIZE - 1):
                self.valid_idxs.append(L)
        self.valid_idxs = np.array(self.valid_idxs, dtype=np.int32)[::stride]
        self.n_idxs = len(self.valid_idxs)
        print(f"# of valid windows: {self.n_idxs}")
        if attacks is not None:
            self.attacks = np.array(attacks, dtype=np.float32)
            self.with_attack = True
        else:
            self.with_attack = False

    def __len__(self):
        return self.n_idxs

    def __getitem__(self, idx):
        i = self.valid_idxs[idx]
        last = i + WINDOW_SIZE - 1
        item = {"attack": self.attacks[last]} if self.with_attack else {}
        item["ts"] = self.ts[i + WINDOW_SIZE - 1]
        item["given"] = torch.from_numpy(self.tag_values[i : i + WINDOW_GIVEN])
        item["answer"] = torch.from_numpy(self.tag_values[last])
        return item

# %%
def boundary_check(df):
    x = np.array(df, dtype=np.float32)
    return np.any(x > 1.0), np.any(x < 0), np.any(np.isnan(x))

# %%
TRAIN_DATASET = sorted([x for x in Path("HAICon2021_dataset/train/").glob("*.csv")])
TRAIN_DATASET
# Out:
# [PosixPath('HAICon2021_dataset/train/train1.csv'),
#  PosixPath('HAICon2021_dataset/train/train2.csv'),
#  PosixPath('HAICon2021_dataset/train/train3.csv'),
#  PosixPath('HAICon2021_dataset/train/train4.csv'),
#  PosixPath('HAICon2021_dataset/train/train5.csv'),
#  PosixPath('HAICon2021_dataset/train/train6.csv')]

# %%
TEST_DATASET = sorted([x for x in Path("HAICon2021_dataset/test/").glob("*.csv")])
TEST_DATASET
# Out:
# [PosixPath('HAICon2021_dataset/test/test1.csv'),
#  PosixPath('HAICon2021_dataset/test/test2.csv'),
#  PosixPath('HAICon2021_dataset/test/test3.csv')]

# %%
VALIDATION_DATASET = sorted([x for x in Path("HAICon2021_dataset/validation/").glob("*.csv")])
VALIDATION_DATASET
# Out:
# [PosixPath('HAICon2021_dataset/validation/validation.csv')]

# %%
def dataframe_from_csv(target):
    return pd.read_csv(target).rename(columns=lambda x: x.strip())

def dataframe_from_csvs(targets):
    return pd.concat([dataframe_from_csv(x) for x in targets])

# %% [markdown]
# # LOAD TRAIN

# %%
TRAIN_DF_RAW = dataframe_from_csvs(TRAIN_DATASET)
TRAIN_DF_RAW
# Out:
#                   timestamp     C01  C02       C03      C04        C05  \
# 0       2021-07-11 10:00:00 -2.2642    0  12.26196 -0.00087   12.01019
# 1       2021-07-11 10:00:01 -2.4923    0  12.26196  0.00058   12.56714
# 2       2021-07-11 10:00:02 -2.8460    0  12.26196 -0.00072   14.48975
# 3       2021-07-11 10:00:03 -2.1235    0  12.26196  0.00101   15.93170
# 4       2021-07-11 10:00:04 -2.9074    0  12.26196  0.00043   16.10718
# ...                     ...     ...  ...       ...      ...        ...
# 259195  2021-08-09 08:59:56 -2.0065    0  12.26196  0.00051  100.28228
# 259196  2021-08-09 08:59:57 -2.2101    0  12.26196 -0.00029  100.28228
# 259197  2021-08-09 08:59:58 -2.3325    0  12.26196  0.00152  100.28228
# 259198  2021-08-09 08:59:59 -2.3049    0  12.26196  0.00058  100.26703
# 259199  2021-08-09 09:00:00 -2.2011    0  12.26196 -0.00014  100.27466
#
#            C06       C07  C08  C09  ...      C77       C78       C79  \
# 0       0.2254  12.66931   70    1  ...  0.92255  30.08042   7.08818
# 1      -0.0711  12.66931   70    1  ...  0.92255  30.08423   7.08818
# 2       0.0051  12.66931   70    1  ...  0.91873  30.09148   7.08818
# 3       0.1842  12.66931   70    1  ...  0.91644  30.10407   7.08818
# 4       0.1842  12.66931   70    1  ...  0.91797  30.10331   7.08818
# ...        ...       ...  ...  ...  ...      ...       ...       ...
# 259195  0.5977  12.53358   70    1  ...  1.17355  35.05434  10.00000
# 259196  0.5509  12.53358   70    1  ...  1.16898  35.03488  10.00000
# 259197  0.5425  12.53358   70    1  ...  1.16974  35.02840  10.00000
# 259198  0.6266  12.53358   70    1  ...  1.16974  35.02420  10.00000
# 259199  0.7209  12.53358   70    1  ...  1.17508  35.01695  10.00000
#
#                C80        C81  C82         C83   C84  C85   C86
# 0        595.06104  276.40338    1  1014.79321  12.0   50  3506
# 1        531.50317  276.18634    1  1014.79321  12.0   50  3493
# 2        451.06253  279.85754    1  1014.79321  12.0   50  3490
# 3        404.38739  281.50317    1  1014.79321  12.0   50  3525
# 4        382.53925  281.34039    1  1014.79321  12.0   50  3503
# ...            ...        ...  ...         ...   ...  ...   ...
# 259195  3178.48877  370.02679    1   986.05908  12.0   50   136
# 259196  3175.36084  370.40656    1   986.05908  12.0   50    89
# 259197  3175.73608  368.12787    1   986.05908  12.0   50    90
# 259198  3176.61182  368.01941    1   986.05908  12.0   50    74
# 259199  3172.23267  367.78424    1   986.05908  12.0   50   101
#
# [1004402 rows x 87 columns]

# %%
TIMESTAMP_FIELD = "timestamp"
IDSTAMP_FIELD = 'id'
ATTACK_FIELD = "attack"
VALID_COLUMNS_IN_TRAIN_DATASET = TRAIN_DF_RAW.columns.drop([TIMESTAMP_FIELD])
VALID_COLUMNS_IN_TRAIN_DATASET
# Out:
# Index(['C01', 'C02', 'C03', 'C04', 'C05', 'C06', 'C07', 'C08', 'C09', 'C10',
#        'C11', 'C12', 'C13', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20',
#        'C21', 'C22', 'C23', 'C24', 'C25', 'C26', 'C27', 'C28', 'C29', 'C30',
#        'C31', 'C32', 'C33', 'C34', 'C35', 'C36', 'C37', 'C38', 'C39', 'C40',
#        'C41', 'C42', 'C43', 'C44', 'C45', 'C46', 'C47', 'C48', 'C49', 'C50',
#        'C51', 'C52', 'C53', 'C54', 'C55', 'C56', 'C57', 'C58', 'C59', 'C60',
#        'C61', 'C62', 'C63', 'C64', 'C65', 'C66', 'C67', 'C68', 'C69', 'C70',
#        'C71', 'C72', 'C73', 'C74', 'C75', 'C76', 'C77', 'C78', 'C79', 'C80',
#        'C81', 'C82', 'C83', 'C84', 'C85', 'C86'],
#       dtype='object')

# %%
TAG_MIN = TRAIN_DF_RAW[VALID_COLUMNS_IN_TRAIN_DATASET].min()
TAG_MAX = TRAIN_DF_RAW[VALID_COLUMNS_IN_TRAIN_DATASET].max()

# %%
def normalize(df):
    ndf = df.copy()
    for c in df.columns:
        if TAG_MIN[c] == TAG_MAX[c]:
            ndf[c] = df[c] - TAG_MIN[c]
        else:
            ndf[c] = (df[c] - TAG_MIN[c]) / (TAG_MAX[c] - TAG_MIN[c])
    return ndf

# %%
TRAIN_DF = normalize(TRAIN_DF_RAW[VALID_COLUMNS_IN_TRAIN_DATASET]).ewm(alpha=0.9).mean()
TRAIN_DF
# Out:
#              C01  C02       C03       C04       C05       C06       C07  C08  \
# 0       0.433107  0.0  0.056338  0.501686  0.116706  0.447955  0.816071  0.0
# 1       0.395098  0.0  0.056338  0.517560  0.121738  0.397053  0.816071  0.0
# 2       0.333267  0.0  0.056338  0.504886  0.139408  0.405431  0.816071  0.0
# 3       0.446345  0.0  0.056338  0.522383  0.154058  0.436703  0.816071  0.0
# 4       0.328324  0.0  0.056338  0.517845  0.157091  0.439827  0.816071  0.0
# ...          ...  ...       ...       ...       ...       ...       ...  ...
# 259195  0.485034  0.0  0.056340  0.515751  0.994085  0.520004  0.640361  0.0
# 259196  0.447224  0.0  0.056338  0.509379  0.994085  0.510481  0.640361  0.0
# 259197  0.423251  0.0  0.056338  0.528358  0.994085  0.508101  0.640361  0.0
# 259198  0.425407  0.0  0.056338  0.520068  0.993949  0.522157  0.640361  0.0
# 259199  0.442746  0.0  0.056338  0.511436  0.994003  0.539590  0.640361  0.0
#
#         C09  C10  ...       C77       C78       C79       C80       C81  C82  \
# 0       0.0  0.0  ...  0.240561  0.194185  0.708818  0.183693  0.169066  0.0
# 1       0.0  0.0  ...  0.240561  0.194535  0.708818  0.165517  0.168332  0.0
# 2       0.0  0.0  ...  0.238319  0.195226  0.708818  0.141083  0.180570  0.0
# 3       0.0  0.0  ...  0.236754  0.196440  0.708818  0.125447  0.187292  0.0
# 4       0.0  0.0  ...  0.237495  0.196492  0.708818  0.117700  0.187419  0.0
# ...     ...  ...  ...       ...       ...       ...       ...       ...  ...
# 259195  0.0  0.0  ...  0.403941  0.696846  1.000000  0.996289  0.517805  0.0
# 259196  0.0  0.0  ...  0.401381  0.695028  1.000000  0.995484  0.518674  0.0
# 259197  0.0  0.0  ...  0.401571  0.694256  1.000000  0.995510  0.511131  0.0
# 259198  0.0  0.0  ...  0.401590  0.693797  1.000000  0.995761  0.510014  0.0
# 259199  0.0  0.0  ...  0.404723  0.693092  1.000000  0.994546  0.509115  0.0
#
#              C83  C84  C85       C86
# 0       0.538147  0.0  0.0  0.276078
# 1       0.538147  0.0  0.0  0.275176
# 2       0.538147  0.0  0.0  0.274889
# 3       0.538147  0.0  0.0  0.277264
# 4       0.538147  0.0  0.0  0.275990
# ...          ...  ...  ...       ...
# 259195  0.414192  0.0  0.0  0.018717
# 259196  0.414192  0.0  0.0  0.015676
# 259197  0.414192  0.0  0.0  0.015440
# 259198  0.414192  0.0  0.0  0.014318
# 259199  0.414192  0.0  0.0  0.016060
#
# [1004402 rows x 86 columns]

# %%
HAI_DATASET_TRAIN = HaiDataset(TRAIN_DF_RAW[TIMESTAMP_FIELD], TRAIN_DF, stride=10)
HAI_DATASET_TRAIN[0]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1004148.0), HTML(value='')))
# # of valid windows: 100288
# {'ts': '2021-07-11 10:04:14',
#  'given': tensor([[0.4331, 0.0000, 0.0563,  ..., 0.0000, 0.0000, 0.2761],
#          [0.3951, 0.0000, 0.0563,  ..., 0.0000, 0.0000, 0.2752],
#          [0.3333, 0.0000, 0.0563,  ..., 0.0000, 0.0000, 0.2749],
#          ...,
#          [0.3126, 0.0000, 0.0563,  ..., 0.0000, 0.0000, 0.0091],
#          [0.4151, 0.0000, 0.0563,  ..., 0.0000, 0.0000, 0.0091],
#          [0.4197, 0.0000, 0.0563,  ..., 0.0000, 0.0000, 0.0091]]),
#  'answer': tensor([0.4201, 0.0000, 0.0563, 0.4333, 0.1376, 0.4077, 0.8161, 0.0000, 0.0000,
#          0.0000, 0.7641, 0.3990, 0.4475, 0.3553, 0.2482, 0.2243, 0.0000, 0.0000,
#          0.0000, 0.3050, 0.3530, 0.0000, 0.2908, 0.6291, 0.0067, 0.0000, 0.2951,
#          0.2689, 0.0000, 0.9763, 0.5345, 0.2550, 0.3436, 0.0000, 0.9009, 0.0000,
#          0.2097, 0.0000, 0.0000, 0.0340, 0.2541, 0.8280, 0.4356, 0.3652, 1.0000,
#          1.0000, 0.4115, 1.0000, 0.0000, 0.0297, 0.4960, 0.0000, 0.6607, 0.1375,
#          0.0000, 0.2578, 0.7985, 0.1781, 0.2675, 0.3467, 1.0000, 0.9041, 0.0000,
#          0.0000, 0.6543, 0.2261, 0.1387, 0.3444, 0.0000, 0.3151, 0.7301, 0.1423,
#          0.4608, 0.1535, 0.2321, 0.2337, 0.3384, 0.2358, 0.7088, 0.1664, 0.4621,
#          0.0000, 0.5381, 0.0000, 0.0000, 0.0091])}

# %% [markdown]
# # LOAD VALID

# %%
VALIDATION_DF_RAW = dataframe_from_csvs(VALIDATION_DATASET)
VALIDATION_DF_RAW
# Out:
#                  timestamp     C01  C02       C03      C04       C05     C06  \
# 0      2021-07-10 00:00:01 -2.0395    0  11.78894  0.00058  16.32080  0.4010
# 1      2021-07-10 00:00:02 -2.1750    0  11.78894 -0.00282  15.95459  0.4187
# 2      2021-07-10 00:00:03 -2.5854    0  11.78131 -0.00398  14.79492  0.0691
# 3      2021-07-10 00:00:04 -2.4722    0  11.78894 -0.00152  14.72626  0.3306
# 4      2021-07-10 00:00:05 -2.2319    0  11.78131  0.00072  14.78729  0.2150
# ...                    ...     ...  ...       ...      ...       ...     ...
# 86395  2021-07-10 23:59:56 -2.8150    0  12.26196  0.00130  15.53497 -0.0507
# 86396  2021-07-10 23:59:57 -2.6272    0  12.26196  0.00109  15.53497  0.1829
# 86397  2021-07-10 23:59:58 -2.3564    0  12.26196 -0.00101  15.53497  0.2907
# 86398  2021-07-10 23:59:59 -2.1541    0  12.26196 -0.00166  15.53497  0.3280
# 86399  2021-07-11 00:00:00 -2.0198    0  12.26196 -0.00195  15.53497  0.3280
#
#              C07  C08  C09  ...       C78       C79         C80        C81  \
# 0      12.903438   70    1  ...  31.52100  0.716042   386.51172  356.64423
# 1      12.903438   70    1  ...  31.51756  0.716042   411.33905  352.08698
# 2      12.903438   70    1  ...  31.50269  0.716042   438.15259  347.63818
# 3      12.903438   70    1  ...  31.47942  0.716042   465.95908  340.33203
# 4      12.903438   70    1  ...  31.47942  0.716042   452.05582  335.17798
# ...          ...  ...  ...  ...       ...       ...         ...        ...
# 86395  12.669310   70    1  ...  31.79814  0.716042  1193.48230  347.58386
# 86396  12.669310   70    1  ...  31.79738  0.716042  1179.76929  348.03607
# 86397  12.669310   70    1  ...  31.78784  0.716042  1152.66187  348.81366
# 86398  12.669310   70    1  ...  31.77029  0.716042  1130.65723  349.13916
# 86399  12.669310   70    1  ...  31.76915  0.716042  1106.10132  346.82434
#
#        C82          C83   C84  C85  C86  attack
# 0        1  1034.712769  12.0   50  161       0
# 1        1  1034.712769  12.0   50  155       0
# 2        1  1034.712769  12.0   50  149       0
# 3        1  1034.712769  12.0   50  148       0
# 4        1  1034.712769  12.0   50  148       0
# ...    ...          ...   ...  ...  ...     ...
# 86395    1  1018.394040  12.0   50    7       0
# 86396    1  1018.394040  12.0   50    7       0
# 86397    1  1018.394040  12.0   50    7       0
# 86398    1  1018.394040  12.0   50    7       0
# 86399    1  1018.394040  12.0   50    7       0
#
# [86400 rows x 88 columns]

# %%
VALIDATION_DF = normalize(VALIDATION_DF_RAW[VALID_COLUMNS_IN_TRAIN_DATASET]).ewm(alpha=0.9).mean()

# %% [markdown]
# # LOAD TEST

# %%
TEST_DF_RAW = dataframe_from_csvs(TEST_DATASET)
TEST_DF_RAW
# Out:
#                   timestamp     C01  C02       C03      C04       C05     C06  \
# 0       2021-07-13 16:00:01 -2.1424    0  12.37640 -0.00275   8.02002  0.1524
# 1       2021-07-13 16:00:02 -2.0449    0  12.37640 -0.00087   8.02002  0.1281
# 2       2021-07-13 16:00:03 -2.1287    0  12.37640 -0.00260   8.02002  0.0148
# 3       2021-07-13 16:00:04 -2.1287    0  12.37640 -0.00282   8.02002  0.0148
# 4       2021-07-13 16:00:05 -2.5969    0  12.37640  0.00058   8.02002 -0.2225
# ...                     ...     ...  ...       ...      ...       ...     ...
# 129595  2021-07-16 23:59:56 -1.8328    0  12.07123  0.00036  15.03143  0.8050
# 129596  2021-07-16 23:59:57 -1.8328    0  12.07123 -0.00470  13.74206  0.8050
# 129597  2021-07-16 23:59:58 -1.5833    0  12.07123 -0.00130  13.64288  0.9984
# 129598  2021-07-16 23:59:59 -1.4022    0  12.07123  0.00087  13.62762  1.0595
# 129599  2021-07-17 00:00:00 -1.2356    0  12.07123  0.00051  14.77966  1.1439
#
#              C07  C08  C09  ...      C77       C78      C79         C80  \
# 0       12.58874   70    1  ...  1.13464  29.09910  2.85153   227.61664
# 1       12.58874   70    1  ...  1.13312  29.14869  2.85153   231.58908
# 2       12.58874   70    1  ...  1.13388  29.18836  2.85153   229.60286
# 3       12.58874   70    1  ...  1.13541  29.24558  2.85153   229.60286
# 4       12.58874   70    1  ...  1.13541  29.24558  2.85153   222.65125
# ...          ...  ...  ...  ...      ...       ...      ...         ...
# 129595  12.58870   70    1  ...  0.92941  29.45263  2.40398  1056.03259
# 129596  12.58870   70    1  ...  0.92255  29.45758  2.40398  1026.05530
# 129597  12.58870   70    1  ...  0.92255  29.45034  2.40398   981.37659
# 129598  12.58870   70    1  ...  0.92255  29.43088  2.40398   919.62439
# 129599  12.58870   70    1  ...  0.93399  29.42478  2.40398   873.09271
#
#               C81  C82         C83   C84  C85   C86
# 0       333.51416    1   981.36951  12.0   50  2100
# 1       340.18738    1   981.36951  12.0   50  2165
# 2       347.14990    1   981.36951  12.0   50  2209
# 3       355.90277    1   981.36951  12.0   50  2233
# 4       358.23566    1   981.36951  12.0   50  2290
# ...           ...  ...         ...   ...  ...   ...
# 129595  373.20966    1  1015.06964  12.0   50    22
# 129596  376.66376    1  1015.06964  12.0   50    22
# 129597  377.76691    1  1015.06964  12.0   50    22
# 129598  378.99664    1  1015.06964  12.0   50    22
# 129599  378.21906    1  1015.06964  12.0   50    22
#
# [274800 rows x 87 columns]

# %%
TEST_DF = normalize(TEST_DF_RAW[VALID_COLUMNS_IN_TRAIN_DATASET]).ewm(alpha=0.9).mean()
TEST_DF
# Out:
#              C01  C02       C03       C04       C05       C06       C07  C08  \
# 0       0.455432  0.0  0.079812  0.479046  0.077046  0.434169  0.711769  0.0
# 1       0.471678  0.0  0.079812  0.499628  0.077046  0.429998  0.711769  0.0
# 2       0.459304  0.0  0.079812  0.482713  0.077046  0.410346  0.711769  0.0
# 3       0.458079  0.0  0.079812  0.478654  0.077046  0.408400  0.711769  0.0
# 4       0.380719  0.0  0.079812  0.515098  0.077046  0.367874  0.711769  0.0
# ...          ...  ...       ...       ...       ...       ...       ...  ...
# 129595  0.511523  0.0  0.017216  0.516825  0.147339  0.557125  0.711717  0.0
# 129596  0.512114  0.0  0.017216  0.461690  0.135262  0.557380  0.711717  0.0
# 129597  0.553332  0.0  0.017216  0.493026  0.133167  0.590276  0.711717  0.0
# 129598  0.587329  0.0  0.017216  0.519678  0.132821  0.603950  0.711717  0.0
# 129599  0.618212  0.0  0.017216  0.518442  0.143092  0.619661  0.711717  0.0
#
#         C09  C10  ...       C77       C78       C79       C80       C81  C82  \
# 0       0.0  0.0  ...  0.378726  0.095024  0.285153  0.068104  0.381526  0.0
# 1       0.0  0.0  ...  0.377826  0.099579  0.285153  0.069240  0.404094  0.0
# 2       0.0  0.0  ...  0.378191  0.103601  0.285153  0.068779  0.429462  0.0
# 3       0.0  0.0  ...  0.379124  0.109204  0.285153  0.068734  0.461282  0.0
# 4       0.0  0.0  ...  0.379218  0.109763  0.285153  0.066761  0.472272  0.0
# ...     ...  ...  ...       ...       ...       ...       ...       ...  ...
# 129595  0.0  0.0  ...  0.245764  0.130889  0.240398  0.327644  0.529605  0.0
# 129596  0.0  0.0  ...  0.241081  0.131212  0.240398  0.320111  0.540804  0.0
# 129597  0.0  0.0  ...  0.240613  0.130586  0.240398  0.306708  0.545617  0.0
# 129598  0.0  0.0  ...  0.240566  0.128753  0.240398  0.287885  0.550216  0.0
# 129599  0.0  0.0  ...  0.247268  0.128015  0.240398  0.272828  0.548072  0.0
#
#              C83  C84  C85       C86
# 0       0.393961  0.0  0.0  0.168791
# 1       0.393961  0.0  0.0  0.173300
# 2       0.393961  0.0  0.0  0.176731
# 3       0.393961  0.0  0.0  0.178719
# 4       0.393961  0.0  0.0  0.182832
# ...          ...  ...  ...       ...
# 129595  0.539339  0.0  0.0  0.010225
# 129596  0.539339  0.0  0.0  0.010225
# 129597  0.539339  0.0  0.0  0.010225
# 129598  0.539339  0.0  0.0  0.010225
# 129599  0.539339  0.0  0.0  0.010225
#
# [274800 rows x 86 columns]

# %%
boundary_check(TEST_DF)
# Out:
# (True, True, False)

# %%
params = {'batch_size': 512,
          'shuffle': True,
          'num_workers': 4,
          'pin_memory' : True}
trainloader = DataLoader(HAI_DATASET_TRAIN, **params)

# %%
train_shape = next(iter(trainloader))['given'].shape
print(train_shape)
# Out:
# torch.Size([512, 254, 86])

# %% [markdown]
# ## Model

# %%
class HAIGPT(nn.Module):

    def __init__(
            self,
            input_dim,
            hidden_size,
            max_len=254,
            device='cuda',
            **kwargs
    ):
        super().__init__()
        self.input_dim = input_dim
        self.hidden_size = hidden_size
        self.device = device
        config = transformers.GPT2Config(
            vocab_size=1,  # doesn't matter -- we don't use the vocab
            n_embd=hidden_size,
            **kwargs
        )

        # note: the only difference between this GPT2Model and the default Huggingface version
        # is that the positional embeddings are removed (since we'll add those ourselves)
        self.transformer = GPT2Model(config)

        self.pos_embedding = nn.Parameter(torch.randn(1, max_len, hidden_size))
        self.embed_token = nn.Linear(self.input_dim, hidden_size)

        self.embed_ln = nn.LayerNorm(hidden_size)

        self.predict = nn.Linear(hidden_size, self.input_dim)

    def forward(self, token, attention_mask=None):

        batch_size, seq_length = token.shape[0], token.shape[1]

        if attention_mask is None:
            # attention mask for GPT: 1 if can be attended to, 0 if not
            attention_mask = torch.ones((batch_size, seq_length), dtype=torch.long).to(self.device)

        # embed each modality with a different head
        token_embeddings = self.embed_token(token)

        # time embeddings are treated similar to positional embeddings
        token_embeddings = token_embeddings + self.pos_embedding

        # which works nice in an autoregressive sense since states predict actions
        inputs = self.embed_ln(token_embeddings)

        # we feed in the input embeddings (not word indices as in NLP) to the model
        transformer_outputs = self.transformer(
            inputs_embeds=inputs,
            attention_mask=attention_mask,
        )
        x = transformer_outputs['last_hidden_state']
        
        # get predictions
        preds = self.predict(x)  

        return preds[:,-1]

# %%
train_shape[1:]
# Out:
# torch.Size([254, 86])

# %%
input_shape = train_shape[1:]
model = HAIGPT(
    input_dim=input_shape[-1],
    hidden_size=128,
    max_len=254,
    n_layer=3,
    n_head=1,
    n_inner=4*128,
    activation_function='relu',
    n_positions=1024,
    resid_pdrop=0.1,
    attn_pdrop=0.1,
).to(device)

# %%
print(model)
# Out:
# HAIGPT(
#   (transformer): GPT2Model(
#     (wte): Embedding(1, 128)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   )
#   (embed_token): Linear(in_features=86, out_features=128, bias=True)
#   (embed_ln): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (predict): Linear(in_features=128, out_features=86, bias=True)
# )

# %%
optimizer = optim.AdamW(model.parameters())
loss_fn = nn.MSELoss()

# %%
print(model(next(iter(trainloader))['given'].to(device)).shape)
# Out:
# torch.Size([512, 86])

# %%
def train(model, train_data, optimizer, loss_fn, use_fp16=True, max_norm=None):
    
    epoch_loss = 0
    
    model.train() 

    for idx, batch in enumerate(train_data):
        
        optimizer.zero_grad(set_to_none=True)
        scaler = torch.cuda.amp.GradScaler()
                
        input = batch['given'].to(device)
        answer = batch["answer"].to(device)
        
        with torch.cuda.amp.autocast(enabled=use_fp16):
            predictions = model.forward(input)
            train_loss = loss_fn(predictions, answer)
        if use_fp16:
            scaler.scale(train_loss).backward()
            if max_norm is not None:
                scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm)
            scaler.step(optimizer)
            scaler.update()
        else:
            train_loss.backward()
            optimizer.step()
        
        epoch_loss += train_loss.item()
        
    return epoch_loss

# %%
def validation(model, val_data, loss_fn):
    model.eval()
    val_loss = 0
    for idx, batch in enumerate(val_data):
        input = batch['given'].to(device)
        answer = batch["answer"].to(device)
        with torch.no_grad():
            predictions = model.forward(input)
            val_loss += loss_fn(predictions, answer).item()
        
    return val_loss

# %%
class EarlyStopping():
    def __init__(self, patience=0, verbose=0):
        self._step = 0
        self._loss = float('inf')
        self.patience = patience
        self.verbose = verbose

    def validate(self, loss):
        if self._loss < loss:
            self._step += 1
            if self._step > self.patience:
                if self.verbose:
                    print(f'\n Training process is stopped early....')
                return True
        else:
            self._step = 0
            self._loss = loss

        return False

# %%
# %%time
# epochs = 300
# history = dict()
# best = {"loss": sys.float_info.max}
# early_stopping = EarlyStopping(patience=30, verbose=1)
# for epoch in range(1, epochs+1):
#     epoch_loss = train(model, trainloader, optimizer, loss_fn, use_fp16=False)
#     val_loss = validation(model, validloader, loss_fn)
    
#     history.setdefault('loss', []).append(epoch_loss) 
#     history.setdefault('val_loss', []).append(val_loss) 
    
#     sys.stdout.write(
#         "\r" + f"[Train] Epoch : {epoch:^3}"\
#         f"  Train Loss: {epoch_loss:.4}"\
#         f"  Validation Loss: {val_loss:.4}"\
#                     )
# #     print(f"[Train] Epoch : {epoch:^3}"\
# #         f"  Train Loss: {epoch_loss:.4}"\
# #         f"  Validation Loss: {val_loss:.4}")
#     if epoch_loss < best["loss"]:
#             best["state"] = model.state_dict()
#             best["loss"] = epoch_loss
#             best["epoch"] = epoch + 1
#     if early_stopping.validate(epoch_loss):
#         break

# %%
# plt.plot(history["loss"], label="Training Loss")
# plt.plot(history["val_loss"], label="Validation Loss")
# plt.legend()
# plt.show()

# %%
# after training
# model.load_state_dict(best["state"])

# %%
# load chkpoint
# model.load_state_dict(torch.load('./checkpoints/GPT_89.tar')['model'])
model.load_state_dict(torch.load('GPT_254.tar')['model'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Validation

# %%
VALIDATION_DF_RAW
# Out:
#                  timestamp     C01  C02       C03      C04       C05     C06  \
# 0      2021-07-10 00:00:01 -2.0395    0  11.78894  0.00058  16.32080  0.4010
# 1      2021-07-10 00:00:02 -2.1750    0  11.78894 -0.00282  15.95459  0.4187
# 2      2021-07-10 00:00:03 -2.5854    0  11.78131 -0.00398  14.79492  0.0691
# 3      2021-07-10 00:00:04 -2.4722    0  11.78894 -0.00152  14.72626  0.3306
# 4      2021-07-10 00:00:05 -2.2319    0  11.78131  0.00072  14.78729  0.2150
# ...                    ...     ...  ...       ...      ...       ...     ...
# 86395  2021-07-10 23:59:56 -2.8150    0  12.26196  0.00130  15.53497 -0.0507
# 86396  2021-07-10 23:59:57 -2.6272    0  12.26196  0.00109  15.53497  0.1829
# 86397  2021-07-10 23:59:58 -2.3564    0  12.26196 -0.00101  15.53497  0.2907
# 86398  2021-07-10 23:59:59 -2.1541    0  12.26196 -0.00166  15.53497  0.3280
# 86399  2021-07-11 00:00:00 -2.0198    0  12.26196 -0.00195  15.53497  0.3280
#
#              C07  C08  C09  ...       C78       C79         C80        C81  \
# 0      12.903438   70    1  ...  31.52100  0.716042   386.51172  356.64423
# 1      12.903438   70    1  ...  31.51756  0.716042   411.33905  352.08698
# 2      12.903438   70    1  ...  31.50269  0.716042   438.15259  347.63818
# 3      12.903438   70    1  ...  31.47942  0.716042   465.95908  340.33203
# 4      12.903438   70    1  ...  31.47942  0.716042   452.05582  335.17798
# ...          ...  ...  ...  ...       ...       ...         ...        ...
# 86395  12.669310   70    1  ...  31.79814  0.716042  1193.48230  347.58386
# 86396  12.669310   70    1  ...  31.79738  0.716042  1179.76929  348.03607
# 86397  12.669310   70    1  ...  31.78784  0.716042  1152.66187  348.81366
# 86398  12.669310   70    1  ...  31.77029  0.716042  1130.65723  349.13916
# 86399  12.669310   70    1  ...  31.76915  0.716042  1106.10132  346.82434
#
#        C82          C83   C84  C85  C86  attack
# 0        1  1034.712769  12.0   50  161       0
# 1        1  1034.712769  12.0   50  155       0
# 2        1  1034.712769  12.0   50  149       0
# 3        1  1034.712769  12.0   50  148       0
# 4        1  1034.712769  12.0   50  148       0
# ...    ...          ...   ...  ...  ...     ...
# 86395    1  1018.394040  12.0   50    7       0
# 86396    1  1018.394040  12.0   50    7       0
# 86397    1  1018.394040  12.0   50    7       0
# 86398    1  1018.394040  12.0   50    7       0
# 86399    1  1018.394040  12.0   50    7       0
#
# [86400 rows x 88 columns]

# %%
ATTACK_LABELS = VALIDATION_DF_RAW['attack']
Counter(ATTACK_LABELS)
# Out:
# Counter({0: 85515, 1: 885})

# %%
VALIDATION_DF
# Out:
#             C01  C02       C03       C04       C05       C06       C07  C08  \
# 0      0.474293  0.0 -0.040688  0.519147  0.159551  0.481116  1.119160  0.0
# 1      0.451714  0.0 -0.040688  0.481925  0.156242  0.484154  1.119160  0.0
# 2      0.381911  0.0 -0.042098  0.465987  0.145560  0.424951  1.119160  0.0
# 3      0.393676  0.0 -0.040829  0.491074  0.143888  0.463538  1.119160  0.0
# 4      0.434492  0.0 -0.042110  0.517858  0.144267  0.447745  1.119160  0.0
# ...         ...  ...       ...       ...       ...       ...       ...  ...
# 86395  0.330458  0.0  0.056340  0.526499  0.151740  0.395722  0.816071  0.0
# 86396  0.362960  0.0  0.056338  0.525410  0.151740  0.435508  0.816071  0.0
# 86397  0.410882  0.0  0.056338  0.502541  0.151740  0.457808  0.816071  0.0
# 86398  0.449047  0.0  0.056338  0.493209  0.151740  0.466378  0.816071  0.0
# 86399  0.475018  0.0  0.056338  0.489133  0.151740  0.467235  0.816071  0.0
#
#        C09  C10  ...       C77       C78       C79       C80       C81  C82  \
# 0      0.0  0.0  ...  0.437871  0.339753  0.071604  0.118089  0.467573  0.0
# 1      0.0  0.0  ...  0.437871  0.339437  0.071604  0.125189  0.452160  0.0
# 2      0.0  0.0  ...  0.431603  0.338055  0.071604  0.133427  0.435862  0.0
# 3      0.0  0.0  ...  0.423829  0.335802  0.071604  0.142116  0.409784  0.0
# 4      0.0  0.0  ...  0.424389  0.335577  0.071604  0.139048  0.389922  0.0
# ...    ...  ...  ...       ...       ...       ...       ...       ...  ...
# 86395  0.0  0.0  ...  0.459111  0.367795  0.071604  0.372276  0.434196  0.0
# 86396  0.0  0.0  ...  0.458786  0.367692  0.071604  0.368093  0.435414  0.0
# 86397  0.0  0.0  ...  0.459199  0.366815  0.071604  0.360001  0.438139  0.0
# 86398  0.0  0.0  ...  0.458795  0.365131  0.071604  0.352961  0.439501  0.0
# 86399  0.0  0.0  ...  0.458303  0.364859  0.071604  0.345305  0.431887  0.0
#
#             C83  C84  C85       C86
# 0      0.624077  0.0  0.0  0.020832
# 1      0.624077  0.0  0.0  0.020416
# 2      0.624077  0.0  0.0  0.019966
# 3      0.624077  0.0  0.0  0.019852
# 4      0.624077  0.0  0.0  0.019841
# ...         ...  ...  ...       ...
# 86395  0.553681  0.0  0.0  0.009081
# 86396  0.553681  0.0  0.0  0.009081
# 86397  0.553681  0.0  0.0  0.009081
# 86398  0.553681  0.0  0.0  0.009081
# 86399  0.553681  0.0  0.0  0.009081
#
# [86400 rows x 86 columns]

# %%
VALID_INFERENCE = VALIDATION_DF.copy()
VALID_INFERENCE=VALID_INFERENCE.reset_index(drop=True)
VALID_INFERENCE.head()
# Out:
#         C01  C02       C03       C04       C05       C06      C07  C08  C09  \
# 0  0.474293  0.0 -0.040688  0.519147  0.159551  0.481116  1.11916  0.0  0.0
# 1  0.451714  0.0 -0.040688  0.481925  0.156242  0.484154  1.11916  0.0  0.0
# 2  0.381911  0.0 -0.042098  0.465987  0.145560  0.424951  1.11916  0.0  0.0
# 3  0.393676  0.0 -0.040829  0.491074  0.143888  0.463538  1.11916  0.0  0.0
# 4  0.434492  0.0 -0.042110  0.517858  0.144267  0.447745  1.11916  0.0  0.0
#
#    C10  ...       C77       C78       C79       C80       C81  C82       C83  \
# 0  0.0  ...  0.437871  0.339753  0.071604  0.118089  0.467573  0.0  0.624077
# 1  0.0  ...  0.437871  0.339437  0.071604  0.125189  0.452160  0.0  0.624077
# 2  0.0  ...  0.431603  0.338055  0.071604  0.133427  0.435862  0.0  0.624077
# 3  0.0  ...  0.423829  0.335802  0.071604  0.142116  0.409784  0.0  0.624077
# 4  0.0  ...  0.424389  0.335577  0.071604  0.139048  0.389922  0.0  0.624077
#
#    C84  C85       C86
# 0  0.0  0.0  0.020832
# 1  0.0  0.0  0.020416
# 2  0.0  0.0  0.019966
# 3  0.0  0.0  0.019852
# 4  0.0  0.0  0.019841
#
# [5 rows x 86 columns]

# %%
len(list(np.around(np.arange(0.010, 0.020, 0.00005),5)))
# Out:
# 200

# %%
WINDOW_GIVEN = 254
WINDOW_SIZE = 255

VAL_LEN = VALID_INFERENCE.shape[0]

best_thres = 0
best_f1 = 0

for THRESHOLD in list(np.around(np.arange(0.010, 0.020, 0.00005),5)):
    print(f'----------THRESHOLD : {THRESHOLD}----------')
    val_att = []

    for i in range(0, VAL_LEN - WINDOW_GIVEN):
        #초기화
        attack = 0

        # model loads
        given = np.array(VALID_INFERENCE.iloc[i:i+WINDOW_GIVEN])
        answer = np.array(VALID_INFERENCE.iloc[i+WINDOW_GIVEN])

        # match shape
        given = torch.from_numpy(given).float().unsqueeze(0).to(device)
        answer = torch.from_numpy(answer).unsqueeze(0).to(device)

        guess = model(given) 

        # diff
        diff = torch.abs(answer - guess)
        diff = np.mean(diff.cpu().detach().numpy())
        #print(f'i : {i} & diff : {diff}')

        if diff >= THRESHOLD:
            attack = 1
            VALID_INFERENCE.iloc[i+WINDOW_GIVEN] = np.array(guess.squeeze(0).cpu().detach().numpy())

        val_att.append(attack)

    # fill blanks
    add_zeros = [0]*WINDOW_GIVEN
    FINAL_LABELS = np.concatenate((add_zeros, val_att), axis=None)
    
    # print
    print(f'>>>> ATTACK_LABELS : {Counter(ATTACK_LABELS)}')
    print(f'>>>> FINAL_LABELS : {Counter(FINAL_LABELS)}')
    
    #  check
    if ATTACK_LABELS.shape[0] == FINAL_LABELS.shape[0]:
        TaPR = etapr.evaluate_haicon(anomalies=ATTACK_LABELS, predictions=FINAL_LABELS)
        print(f">>> F1: {TaPR['f1']:.3f} (TaP: {TaPR['TaP']:.3f}, TaR: {TaPR['TaR']:.3f})")
        print(f">>> # of detected anomalies: {len(TaPR['Detected_Anomalies'])}")
        print(f">>> Detected anomalies: {TaPR['Detected_Anomalies']}")
        
        if TaPR['f1']>best_f1:
            best_thres = THRESHOLD
            best_f1 = TaPR['f1']
            print("***Best Threshold updated!!***")
# Out:
# ----------THRESHOLD : 0.01----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({1: 44989, 0: 41411})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01005----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 45488, 1: 40912})
# >>> F1: 0.006 (TaP: 0.003, TaR: 0.161)
# >>> # of detected anomalies: 2
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f946445d828>, <TaPR_pkg.DataManage.Range.Range object at 0x7f946445d278>]
# ***Best Threshold updated!!***
# ----------THRESHOLD : 0.0101----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 43382, 1: 43018})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01015----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({1: 50729, 0: 35671})
# >>> F1: 0.015 (TaP: 0.008, TaR: 0.265)
# >>> # of detected anomalies: 2
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f94653c6278>, <TaPR_pkg.DataManage.Range.Range object at 0x7f94653c65f8>]
# ***Best Threshold updated!!***
# ----------THRESHOLD : 0.0102----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({1: 51596, 0: 34804})
# >>> F1: 0.013 (TaP: 0.007, TaR: 0.215)
# >>> # of detected anomalies: 2
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f94653c04a8>, <TaPR_pkg.DataManage.Range.Range object at 0x7f94653c0588>]
# ----------THRESHOLD : 0.01025----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({1: 49625, 0: 36775})
# >>> F1: 0.005 (TaP: 0.002, TaR: 0.099)
# >>> # of detected anomalies: 1
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f9464457c88>]
# ----------THRESHOLD : 0.0103----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 45404, 1: 40996})
# >>> F1: 0.015 (TaP: 0.007, TaR: 0.438)
# >>> # of detected anomalies: 4
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f946444e9e8>, <TaPR_pkg.DataManage.Range.Range object at 0x7f946444eba8>, <TaPR_pkg.DataManage.Range.Range object at 0x7f946444ed68>, <TaPR_pkg.DataManage.Range.Range object at 0x7f946444ee48>]
# ----------THRESHOLD : 0.01035----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({1: 47631, 0: 38769})
# >>> F1: 0.005 (TaP: 0.002, TaR: 0.140)
# >>> # of detected anomalies: 2
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f94653cf128>, <TaPR_pkg.DataManage.Range.Range object at 0x7f94653cf208>]
# ----------THRESHOLD : 0.0104----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 47017, 1: 39383})
# >>> F1: 0.009 (TaP: 0.005, TaR: 0.146)
# >>> # of detected anomalies: 2
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f94653eb3c8>, <TaPR_pkg.DataManage.Range.Range object at 0x7f94653eb668>]
# ----------THRESHOLD : 0.01045----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 47654, 1: 38746})
# >>> F1: 0.006 (TaP: 0.003, TaR: 0.146)
# >>> # of detected anomalies: 2
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f946444acf8>, <TaPR_pkg.DataManage.Range.Range object at 0x7f946444a748>]
# ----------THRESHOLD : 0.0105----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 46214, 1: 40186})
# >>> F1: 0.003 (TaP: 0.002, TaR: 0.142)
# >>> # of detected anomalies: 2
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f94653dc2e8>, <TaPR_pkg.DataManage.Range.Range object at 0x7f94653dc828>]
# ----------THRESHOLD : 0.01055----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({1: 46410, 0: 39990})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0106----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({1: 45470, 0: 40930})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01065----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 45303, 1: 41097})
# >>> F1: 0.009 (TaP: 0.004, TaR: 0.107)
# >>> # of detected anomalies: 1
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f93a3d15780>]
# ----------THRESHOLD : 0.0107----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 49355, 1: 37045})
# >>> F1: 0.004 (TaP: 0.002, TaR: 0.091)
# >>> # of detected anomalies: 1
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f94652f40b8>]
# ----------THRESHOLD : 0.01075----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 53848, 1: 32552})
# >>> F1: 0.002 (TaP: 0.001, TaR: 0.073)
# >>> # of detected anomalies: 1
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f9465376ba8>]
# ----------THRESHOLD : 0.0108----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 48699, 1: 37701})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01085----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 48102, 1: 38298})
# >>> F1: 0.006 (TaP: 0.003, TaR: 0.104)
# >>> # of detected anomalies: 1
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f946511b1d0>]
# ----------THRESHOLD : 0.0109----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 61058, 1: 25342})
# >>> F1: 0.006 (TaP: 0.003, TaR: 0.127)
# >>> # of detected anomalies: 2
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f946443f198>, <TaPR_pkg.DataManage.Range.Range object at 0x7f946443f3c8>]
# ----------THRESHOLD : 0.01095----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 52343, 1: 34057})
# >>> F1: 0.004 (TaP: 0.002, TaR: 0.098)
# >>> # of detected anomalies: 1
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f94644427b8>]
# ----------THRESHOLD : 0.011----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 43384, 1: 43016})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01105----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 52372, 1: 34028})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0111----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 49877, 1: 36523})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01115----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 57824, 1: 28576})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0112----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 60166, 1: 26234})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01125----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 60807, 1: 25593})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0113----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 57632, 1: 28768})
# >>> F1: 0.008 (TaP: 0.004, TaR: 0.077)
# >>> # of detected anomalies: 1
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f94644613c8>]
# ----------THRESHOLD : 0.01135----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 62244, 1: 24156})
# >>> F1: 0.006 (TaP: 0.003, TaR: 0.067)
# >>> # of detected anomalies: 1
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f94644665c0>]
# ----------THRESHOLD : 0.0114----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 59255, 1: 27145})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01145----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 65227, 1: 21173})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0115----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 64080, 1: 22320})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01155----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 68616, 1: 17784})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0116----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 61832, 1: 24568})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01165----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 71344, 1: 15056})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0117----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 62506, 1: 23894})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01175----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 72541, 1: 13859})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0118----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 64485, 1: 21915})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01185----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 64927, 1: 21473})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0119----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 68350, 1: 18050})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01195----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 70630, 1: 15770})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.012----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 66526, 1: 19874})
# >>> F1: 0.009 (TaP: 0.005, TaR: 0.087)
# >>> # of detected anomalies: 1
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f93b5301438>]
# ----------THRESHOLD : 0.01205----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 65875, 1: 20525})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0121----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 68340, 1: 18060})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01215----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 70310, 1: 16090})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0122----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 67871, 1: 18529})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01225----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 67379, 1: 19021})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0123----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 69704, 1: 16696})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01235----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 74362, 1: 12038})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0124----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 70483, 1: 15917})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01245----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 68087, 1: 18313})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0125----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 74749, 1: 11651})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01255----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 69985, 1: 16415})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0126----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 76702, 1: 9698})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01265----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 79952, 1: 6448})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0127----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 65894, 1: 20506})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01275----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 70865, 1: 15535})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0128----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 77373, 1: 9027})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01285----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 83353, 1: 3047})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0129----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 74644, 1: 11756})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01295----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 74957, 1: 11443})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.013----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 71008, 1: 15392})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01305----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 82768, 1: 3632})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0131----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 78197, 1: 8203})
# >>> F1: 0.006 (TaP: 0.003, TaR: 0.044)
# >>> # of detected anomalies: 1
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f946538d7b8>]
# ----------THRESHOLD : 0.01315----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 75417, 1: 10983})
# >>> F1: 0.023 (TaP: 0.013, TaR: 0.090)
# >>> # of detected anomalies: 1
# >>> Detected anomalies: [<TaPR_pkg.DataManage.Range.Range object at 0x7f94653925c0>]
# ***Best Threshold updated!!***
# ----------THRESHOLD : 0.0132----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 81372, 1: 5028})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01325----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 78894, 1: 7506})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0133----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 74574, 1: 11826})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01335----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 79082, 1: 7318})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0134----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 80685, 1: 5715})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01345----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 82984, 1: 3416})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0135----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 76681, 1: 9719})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01355----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 80359, 1: 6041})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0136----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 80828, 1: 5572})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01365----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 78658, 1: 7742})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0137----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 84846, 1: 1554})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01375----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 77714, 1: 8686})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0138----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85196, 1: 1204})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01385----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 80690, 1: 5710})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0139----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 80196, 1: 6204})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01395----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 84800, 1: 1600})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.014----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 82855, 1: 3545})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01405----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 83824, 1: 2576})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0141----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 79967, 1: 6433})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01415----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85765, 1: 635})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0142----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 81314, 1: 5086})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01425----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 80429, 1: 5971})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0143----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85748, 1: 652})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01435----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 79491, 1: 6909})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0144----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85644, 1: 756})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01445----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 84879, 1: 1521})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0145----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 81473, 1: 4927})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01455----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 84087, 1: 2313})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0146----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 83325, 1: 3075})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01465----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 75873, 1: 10527})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0147----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 81543, 1: 4857})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01475----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85480, 1: 920})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0148----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 82173, 1: 4227})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01485----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 83703, 1: 2697})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0149----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85007, 1: 1393})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01495----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 84125, 1: 2275})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.015----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 79761, 1: 6639})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01505----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 83683, 1: 2717})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0151----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 84839, 1: 1561})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01515----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85954, 1: 446})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0152----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 83291, 1: 3109})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01525----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 82277, 1: 4123})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0153----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 86076, 1: 324})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01535----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85002, 1: 1398})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0154----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 84046, 1: 2354})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01545----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85737, 1: 663})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0155----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 83647, 1: 2753})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01555----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 86124, 1: 276})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0156----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85596, 1: 804})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01565----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 86128, 1: 272})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0157----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 86094, 1: 306})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01575----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 84084, 1: 2316})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0158----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 82896, 1: 3504})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01585----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 84642, 1: 1758})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0159----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 81862, 1: 4538})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01595----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 83623, 1: 2777})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.016----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 84606, 1: 1794})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01605----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85101, 1: 1299})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0161----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85478, 1: 922})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01615----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 86231, 1: 169})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0162----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85036, 1: 1364})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01625----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 86169, 1: 231})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0163----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 86186, 1: 214})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01635----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 80164, 1: 6236})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0164----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85416, 1: 984})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01645----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 81219, 1: 5181})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0165----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85698, 1: 702})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01655----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85675, 1: 725})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0166----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 86148, 1: 252})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01665----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 84811, 1: 1589})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0167----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85865, 1: 535})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01675----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85905, 1: 495})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0168----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 86131, 1: 269})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01685----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 86249, 1: 151})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.0169----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 86231, 1: 169})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01695----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85068, 1: 1332})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.017----------
# >>>> ATTACK_LABELS : Counter({0: 85515, 1: 885})
# >>>> FINAL_LABELS : Counter({0: 85726, 1: 674})
# >>> F1: 0.000 (TaP: 0.000, TaR: 0.000)
# >>> # of detected anomalies: 0
# >>> Detected anomalies: []
# ----------THRESHOLD : 0.01705----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-5920775670af> in <module>
#      23         answer = torch.from_numpy(answer).unsqueeze(0).to(device)
#      24
# ---> 25         guess = model(given)
#      26
#      27         # diff
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# <ipython-input-24-869e1db6533f> in forward(self, token, attention_mask)
#      50         transformer_outputs = self.transformer(
#      51             inputs_embeds=inputs,
# ---> 52             attention_mask=attention_mask,
#      53         )
#      54         x = transformer_outputs['last_hidden_state']
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /repo/projects/HAI_timeseries/src/models/gpt2.py in forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict)
#     739                     encoder_attention_mask=encoder_attention_mask,
#     740                     use_cache=use_cache,
# --> 741                     output_attentions=output_attentions,
#     742                 )
#     743
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     732             if hook_result is not None:
#     733                 result = hook_result
# --> 734         if (len(self._backward_hooks) > 0) or (len(_global_backward_hooks) > 0):
#     735             var = result
#     736             while not isinstance(var, torch.Tensor):
#
# KeyboardInterrupt:

# %%
best_thres = 0.01315

# %% [markdown]
# # Inference

# %%
TEST_INFERENCE = TEST_DF.copy()
TEST_INFERENCE=TEST_INFERENCE.reset_index(drop=True)
TEST_INFERENCE.head()
# Out:
#         C01  C02       C03       C04       C05       C06       C07  C08  C09  \
# 0  0.455432  0.0  0.079812  0.479046  0.077046  0.434169  0.711769  0.0  0.0
# 1  0.471678  0.0  0.079812  0.499628  0.077046  0.429998  0.711769  0.0  0.0
# 2  0.459304  0.0  0.079812  0.482713  0.077046  0.410346  0.711769  0.0  0.0
# 3  0.458079  0.0  0.079812  0.478654  0.077046  0.408400  0.711769  0.0  0.0
# 4  0.380719  0.0  0.079812  0.515098  0.077046  0.367874  0.711769  0.0  0.0
#
#    C10  ...       C77       C78       C79       C80       C81  C82       C83  \
# 0  0.0  ...  0.378726  0.095024  0.285153  0.068104  0.381526  0.0  0.393961
# 1  0.0  ...  0.377826  0.099579  0.285153  0.069240  0.404094  0.0  0.393961
# 2  0.0  ...  0.378191  0.103601  0.285153  0.068779  0.429462  0.0  0.393961
# 3  0.0  ...  0.379124  0.109204  0.285153  0.068734  0.461282  0.0  0.393961
# 4  0.0  ...  0.379218  0.109763  0.285153  0.066761  0.472272  0.0  0.393961
#
#    C84  C85       C86
# 0  0.0  0.0  0.168791
# 1  0.0  0.0  0.173300
# 2  0.0  0.0  0.176731
# 3  0.0  0.0  0.178719
# 4  0.0  0.0  0.182832
#
# [5 rows x 86 columns]

# %%
WINDOW_GIVEN = 254
WINDOW_SIZE = 255
#THRESHOLD = 0.04
THRESHOLD = best_thres

TEST_LEN = TEST_INFERENCE.shape[0]
att = []

for i in trange(0, TEST_LEN - WINDOW_GIVEN):
    #초기화
    attack = 0

    # model loads
    given = np.array(TEST_INFERENCE.iloc[i:i+WINDOW_GIVEN])
    answer = np.array(TEST_INFERENCE.iloc[i+WINDOW_GIVEN])
    
    # match shape
    given = torch.from_numpy(given).float().unsqueeze(0).to(device)
    answer = torch.from_numpy(answer).unsqueeze(0).to(device)
    
    guess = model(given) 

    # diff
    diff = torch.abs(answer - guess)
    diff = np.mean(diff.cpu().detach().numpy())
    #print(f'i : {i} & diff : {diff}')

    if diff >= THRESHOLD:
        attack = 1
        TEST_INFERENCE.iloc[i+WINDOW_GIVEN] = np.array(guess.squeeze(0).cpu().detach().numpy())
    
    att.append(attack)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=274546.0), HTML(value='')))

# %%
add_zeros = [0]*WINDOW_GIVEN
print(len(add_zeros))
# Out:
# 254

# %%
from collections import Counter
Counter(att)
# Out:
# Counter({0: 1, 1: 274545})

# %%
concat_attack = np.concatenate((add_zeros, att), axis=None)
print(len(concat_attack))
print()
print(concat_attack)
# Out:
# 274800
#
# [0 0 0 ... 1 1 1]

# %%
print(TEST_LEN)
print(len(concat_attack))
# Out:
# 274800
# 274800

# %%
Counter(concat_attack)
# Out:
# Counter({0: 255, 1: 274545})

# %%
submission = pd.read_csv('./HAICon2021_dataset/sample_submission.csv')
submission.shape
# Out:
# (274800, 2)

# %%
submission['attack'] = pd.Series(concat_attack)
submission
# Out:
#                   timestamp  attack
# 0       2021-07-13 16:00:01       0
# 1       2021-07-13 16:00:02       0
# 2       2021-07-13 16:00:03       0
# 3       2021-07-13 16:00:04       0
# 4       2021-07-13 16:00:05       0
# ...                     ...     ...
# 274795  2021-07-16 23:59:56       1
# 274796  2021-07-16 23:59:57       1
# 274797  2021-07-16 23:59:58       1
# 274798  2021-07-16 23:59:59       1
# 274799  2021-07-17 00:00:00       1
#
# [274800 rows x 2 columns]

# %%
submission.to_csv(f'GPT_254_renewal_{THRESHOLD}.csv', index=False)

# %%
# torch.save({'model': model.state_dict(), 
#                 'Threshold': 0.025, 
#                }, './checkpoints/GPT_89.tar')

# %% [markdown]
# ----
